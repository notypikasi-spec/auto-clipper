# %% [markdown]
# <a href="https://colab.research.google.com/github/notypikasi-spec/auto-clipper/blob/main/rewindshort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# ==============================================================================
# SCRIPT PENYELAMAT: FIX ATTRIBUTE ERROR & INSTALL LIBRARY
# ==============================================================================
import subprocess
import sys

def super_setup():
    print("🧹 Membersihkan sisa error & Menginstal library versi stabil...")

    # Memaksa instalasi tiktoken & transformers versi tertentu untuk fix AttributeError
    packages = [
        "openai-whisper",
        "transformers==4.37.2",
        "tiktoken==0.6.0",
        "yt-dlp",
        "moviepy==1.0.3",
        "opencv-python"
    ]

    for p in packages:
        subprocess.check_call([sys.executable, "-m", "pip", "install", p, "--quiet"])

    # Setting ImageMagick agar subtitle muncul
    print("🎨 Menyiapkan sistem teks...")
    # !apt-get install imagemagick -y > /dev/null
    # !sed -i 's/<policy domain="path" rights="none" pattern="@\*"/<policy domain="path" rights="read|write" pattern="@\*"/g' /etc/ImageMagick-6/policy.xml

    print("✅ RESET BERHASIL! Silakan jalankan kodingan Clipper kamu.")

super_setup()
# Out:
# 🧹 Membersihkan sisa error & Menginstal library versi stabil...
# 🎨 Menyiapkan sistem teks...
# ✅ RESET BERHASIL! Silakan jalankan kodingan Clipper kamu.
